# %% [markdown]
# # NDVI Exploration and Analysis
#
# This notebook provides examples of NDVI computation and visualization using the VerdeMetria package.
#
# ## Setup
#
# Before running this notebook:
#
# 1. Ensure you have activated the conda environment:
#    ```bash
#    conda activate ndvi
#    ```
#
# 2. Download sample data (see README.md for instructions)
#
# 3. Place red and NIR band files in `data/raw/`

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../src')

from verdemetria import compute_ndvi_array, read_raster, write_raster

# %matplotlib inline

# %% [markdown]
# ## Load Data
#
# Replace paths with your actual data files.

# %%
# Example paths - update these with your actual files
# red_path = '../data/raw/sentinel2_B04.tif'
# nir_path = '../data/raw/sentinel2_B08.tif'

# Uncomment to load:
# red, red_profile = read_raster(red_path)
# nir, nir_profile = read_raster(nir_path)

print("Update paths above and uncomment to load your data")

# %% [markdown]
# ## Compute NDVI

# %%
# Compute NDVI
# ndvi = compute_ndvi_array(red, nir)
# print(f"NDVI shape: {ndvi.shape}")
# print(f"NDVI range: [{np.nanmin(ndvi):.3f}, {np.nanmax(ndvi):.3f}]")

# %% [markdown]
# ## Visualize Results

# %%
# Visualize NDVI
# fig, ax = plt.subplots(figsize=(10, 8))
# im = ax.imshow(ndvi, cmap='RdYlGn', vmin=-1, vmax=1)
# plt.colorbar(im, ax=ax, label='NDVI')
# ax.set_title('NDVI Map')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Save Results

# %%
# Save NDVI to file
# write_raster(ndvi, red_profile, '../outputs/ndvi_notebook.tif')
# print("NDVI saved to outputs/ndvi_notebook.tif")

# %% [markdown]
# ## Next Steps
#
# - Run temporal analysis with multiple dates
# - Calculate vegetation change statistics
# - Export results for GIS visualization
#
# See README.md for more examples and workflows.
